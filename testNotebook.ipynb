# %%
# imports :
import pandas as pd
from child_abuse_detection.text_utils import pars_csv, clean_text
from sklearn.model_selection import train_test_split

# %%
df_abuse = pars_csv("ChildAbuse")
df_normal = pars_csv("SampleNews")
clean_df_abuse = clean_text(df_abuse)
clean_df_normal = clean_text(df_normal)
df_total = pd.concat([clean_df_abuse, clean_df_normal], sort=False)
df_total.reset_index(inplace=True)
print(len(clean_df_normal), len(clean_df_abuse))
# xs = df_total["content"]
# ys = df_total["is_childAbuse"]
# x_train, x_test, y_train, y_test = train_test_split(xs, ys,
#                                                     test_size=0.25,
#                                                     random_state=42,
#                                                     stratify=ys)
                                                    
# s = [x_train, x_test, y_train, y_test]
# for i in s:
#     print(len(i))
df_total
# Out:
# 1018 121
#       index                                            content  is_childAbuse
# 0         0  پرده ماجرای مادر رحم مشهدی تصاویر کودک آزاری ف...              1
# 1         1  گزارش خبرنگار حوزه اخبار داغ گروه فضای مجازی ب...              1
# 2         2  لادن طباطبایی کودک آزادی مرد شیطان صفت لادن طب...              1
# 3         3                                                                 1
# 4         4  خبر ویدئوهای اذیت آزار کودک چینی مرکز نگهداری ...              1
# ...     ...                                                ...            ...
# 1134   1013  تیپ خفن بهاره رهنما ترکیه بینید بهاره رهنما آذ...              0
# 1135   1014  تیم ملی ایران دیدار دوستانه مقابل بوسنی توانست...              0
# 1136   1015  سید جلال زننده گل پرسپولیس بازی شهر خودرو درس ...              0
# 1137   1016  محمدجواد ظریف وزیر امور خارجه جمهوری اسلامی ای...              0
# 1138   1017  هفته تعطیلی تهران فرار ویروس کرونا نگرفته جان ...              0
#
# [1139 rows x 3 columns]

# %%
from pycaret.classification import *

pce_1 = setup(data=df_total, target= "is_childAbuse",train_size=0.80, fix_imbalance=True, data_split_stratify=True)
# pce_1 = setup(data=df_total, target= "is_childAbuse",train_size=0.80)
# Out:
# <style type="text/css">
# #T_6ab39_row44_col1, #T_6ab39_row58_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6ab39">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ab39_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6ab39_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ab39_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6ab39_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_6ab39_row0_col1" class="data row0 col1" >564</td>
#     </tr>
#     <tr>
#       <th id="T_6ab39_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6ab39_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6ab39_row1_col1" class="data row1 col1" >is_childAbuse</td>
#     </tr>
#     <tr>
#       <th id="T_6ab39_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_de65e th {
#   text-align: left;
# }
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_c9d98 th {
#   text-align: left;
# }
# ...

# %% [markdown]
# svm
# gradient boosting
# knn
# logistic regression
# decision tree classifier

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_fa801 th {
#   text-align: left;
# }
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_1d171 th {
#   text-align: left;
# }
# ...

# %%
model_gbc = create_model("xgboost")
# Out:
# <style type="text/css">
# #T_e6562_row10_col0, #T_e6562_row10_col1, #T_e6562_row10_col2, #T_e6562_row10_col3, #T_e6562_row10_col4, #T_e6562_row10_col5, #T_e6562_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_e6562">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6562_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_e6562_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_e6562_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_e6562_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_e6562_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_e6562_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_e6562_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
plot_model(model_gbc, 'confusion_matrix')

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_0106f th {
#   text-align: left;
# }
# ...
